# %% [markdown]
# # Data Inspection and Setup
#
# This notebook handles:
# 1. Inspecting dataset structure and statistics
# 2. Finding image-ground truth pairs
# 3. Splitting dataset into train/val/test sets
# 4. Organizing processed data in workspace

# %% [markdown]
# ## Setup and Imports

# %%
import sys
from pathlib import Path

# Add src directory to path
# Notebook is now in data_preparation/notebooks/, so go up 2 levels to get to project root
current_dir = Path.cwd()
if current_dir.name == 'notebooks' and current_dir.parent.name == 'data_preparation':
    project_root = current_dir.parent.parent
else:
    project_root = Path.cwd()
sys.path.append(str(project_root / 'data_preparation' / 'src'))

from data_processor import DatasetProcessor
import json

# %% [markdown]
# ## Load Configuration
#
# Configuration file contains data paths, split ratios, and processing parameters.

# %%
# Load configuration
config_path = project_root / 'configs' / 'data_config.json'
with open(config_path, 'r') as f:
    config = json.load(f)

print("Configuration loaded:")
print(json.dumps(config, indent=2))
# Out:
# Configuration loaded:
# {
#   "data_paths": {
#     "raw_data": "data/raw",
#     "processed_data": "data/processed",
#     "train_data": "data/processed/train",
#     "val_data": "data/processed/val",
#     "test_data": "data/processed/test"
#   },
#   "split_ratios": {
#     "train": 0.7,
#     "val": 0.15,
#     "test": 0.15
#   },
#   "random_state": 42,
#   "preprocessing": {
#     "target_size": [
#       512,
#       512
#     ],
#     "resize_mode": "resize",
#     "target_format": "png",
#     "normalize": true,
#     "grayscale": false
#   },
#   "augmentation": {
#     "enabled": true,
#     "rotation_range": 15,
#     "horizontal_flip": true,
#     "vertical_flip": false,
#     "brightness_range": [
#       0.8,
#       1.2
#     ],
#     "contrast_range": [
#       0.8,
#       1.2
#     ]
#   },
#   "datasets": {
#     "CASIA2": {
#       "enabled": true,
#       "only_copy_move": true
#     },
#     "comofod_small": {
#       "enabled": true,
#       "use_all_variants": true
#     },
#     "COVERAGE": {
#       "enabled": true
#     },
#     "MICC": {
#       "enabled": true,
#       "sub_datasets": [
#         "MICC-F220",
#         "MICC_F600",
#         "MICC-F2000"
#       ]
#     },
#     "FAU": {
#       "enabled": true,
#       "include_benchmark": true,
#       "include_transforms": true
#     }
#   }
# }

# %% [markdown]
# ## Setup Data Directories
#
# Create necessary directories for raw and processed data.

# %%
# Create processed data directories
processed_dir = project_root / config['data_paths']['processed_data']
processed_dir.mkdir(parents=True, exist_ok=True)
(processed_dir / 'train' / 'images').mkdir(parents=True, exist_ok=True)
(processed_dir / 'train' / 'masks').mkdir(parents=True, exist_ok=True)
(processed_dir / 'val' / 'images').mkdir(parents=True, exist_ok=True)
(processed_dir / 'val' / 'masks').mkdir(parents=True, exist_ok=True)
(processed_dir / 'test' / 'images').mkdir(parents=True, exist_ok=True)
(processed_dir / 'test' / 'masks').mkdir(parents=True, exist_ok=True)

print("Data directories created successfully")
# Out:
# Data directories created successfully

# %% [markdown]
# ## Verify Raw Data Location
#
# Ensure raw dataset is placed in the configured data directory.

# %%
# Check if raw data directory exists and has files
raw_data_path = project_root / config['data_paths']['raw_data']

if not raw_data_path.exists():
    print(f"Warning: Raw data directory '{raw_data_path}' does not exist.")
    print(f"Please place your raw dataset in: {raw_data_path.absolute()}")
else:
    datasets = [d for d in raw_data_path.iterdir() if d.is_dir() and d.name != '__pycache__']
    if datasets:
        print(f"Found {len(datasets)} datasets in raw data directory:")
        for dataset in datasets:
            print(f"  - {dataset.name}")
        print(f"Location: {raw_data_path.absolute()}")
    else:
        print(f"Warning: Raw data directory '{raw_data_path}' is empty.")
        print(f"Please place your dataset files in: {raw_data_path.absolute()}")
# Out:
# Found 5 datasets in raw data directory:
#   - CASIA2
#   - comofod_small
#   - FAU
#   - MICC
#   - COVERAGE
# Location: /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/raw

# %% [markdown]
# ## Inspect Dataset
#
# Analyze dataset structure, count image-ground truth pairs, and categorize by manipulation type.

# %%
# Initialize dataset processor
raw_data_path = project_root / config['data_paths']['raw_data']
processed_data_path = project_root / config['data_paths']['processed_data']

processor = DatasetProcessor(
    raw_data_dir=str(raw_data_path),
    processed_data_dir=str(processed_data_path),
    config=config
)

print("Dataset processor initialized")
print(f"Raw data: {raw_data_path}")
print(f"Processed data: {processed_data_path}")
print(f"Target size: {processor.target_size}")
print(f"Target format: {processor.target_format}")
# Out:
# Dataset processor initialized
# Raw data: /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/raw
# Processed data: /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/processed
# Target size: (512, 512)
# Target format: png

# %% [markdown]
# ## Get Image-Ground Truth Pairs
#
# Find all pairs of tampered images and their corresponding ground truth masks.

# %%
# Process all datasets
print("Starting dataset processing...")
print("This will:")
print("  1. Find all image-mask pairs from all datasets")
print("  2. Resize images to target size (if specified)")
print("  3. Convert masks to binary format")
print("  4. Rename files with consistent numbering")
print("  5. Split into train/val/test sets")
print("  6. Copy to processed directory")
print("\nProcessing...")

stats = processor.process_all_datasets()

print("\n" + "="*60)
print("PROCESSING COMPLETE")
print("="*60)
print(f"Total pairs found: {stats['total_pairs']}")
print(f"Successfully processed: {stats['successful_pairs']}")
print(f"Failed: {stats['failed_pairs']}")

if stats['errors']:
    print(f"\nErrors encountered: {len(stats['errors'])}")
    print("First 5 errors:")
    for error in stats['errors'][:5]:
        print(f"  - {error}")
# Out:
# 2025-11-16 18:44:20,899 - INFO - Starting dataset processing pipeline
# 2025-11-16 18:44:20,899 - INFO - Processing CASIA2...
# 2025-11-16 18:44:21,038 - INFO - CASIA2: Found 3216 pairs
# 2025-11-16 18:44:21,038 - INFO - Processing comofod_small...
# Starting dataset processing...
# This will:
#   1. Find all image-mask pairs from all datasets
#   2. Resize images to target size (if specified)
#   3. Convert masks to binary format
#   4. Rename files with consistent numbering
#   5. Split into train/val/test sets
#   6. Copy to processed directory
#
# Processing...
# 2025-11-16 18:44:21,158 - INFO - comofod_small: Found 5000 pairs
# 2025-11-16 18:44:21,158 - INFO - Processing COVERAGE...
# 2025-11-16 18:44:21,161 - INFO - COVERAGE: Found 100 pairs
# 2025-11-16 18:44:21,161 - INFO - Processing MICC...
# 2025-11-16 18:44:21,187 - INFO - MICC: Found 0 pairs
# 2025-11-16 18:44:21,187 - INFO - Processing FAU...
# 2025-11-16 18:44:21,204 - INFO - FAU: Found 54 pairs
# 2025-11-16 18:44:21,204 - INFO - Total pairs found: 8370
# 2025-11-16 18:44:21,207 - INFO - Split: Train=5858, Val=1256, Test=1256
# 2025-11-16 20:11:20,813 - INFO - train: 5858 successful, 0 failed
# 2025-11-16 20:29:30,152 - INFO - val: 1256 successful, 0 failed
# 2025-11-16 20:46:09,842 - INFO - test: 1256 successful, 0 failed
# 2025-11-16 20:46:09,843 - INFO - Processing report saved to /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/processed/processing_report.json
# ============================================================
# PROCESSING COMPLETE
# ============================================================
# Total pairs found: 8370
# Successfully processed: 8370
# Failed: 0

# %% [markdown]
# ## Split Dataset
#
# Split dataset into training, validation, and test sets according to configured ratios.

# %%
# Verify processed data
train_dir = processed_data_path / 'train'
val_dir = processed_data_path / 'val'
test_dir = processed_data_path / 'test'

train_images = len(list((train_dir / 'images').glob('*')))
train_masks = len(list((train_dir / 'masks').glob('*')))
val_images = len(list((val_dir / 'images').glob('*')))
val_masks = len(list((val_dir / 'masks').glob('*')))
test_images = len(list((test_dir / 'images').glob('*')))
test_masks = len(list((test_dir / 'masks').glob('*')))

print("\n" + "="*60)
print("PROCESSED DATA VERIFICATION")
print("="*60)
print(f"Training set:")
print(f"  Images: {train_images}")
print(f"  Masks: {train_masks}")
print(f"  Match: {'✓' if train_images == train_masks else '✗'}")

print(f"\nValidation set:")
print(f"  Images: {val_images}")
print(f"  Masks: {val_masks}")
print(f"  Match: {'✓' if val_images == val_masks else '✗'}")

print(f"\nTest set:")
print(f"  Images: {test_images}")
print(f"  Masks: {test_masks}")
print(f"  Match: {'✓' if test_images == test_masks else '✗'}")

total = train_images + val_images + test_images
print(f"\nTotal processed images: {total}")
# Out:
# ============================================================
# PROCESSED DATA VERIFICATION
# ============================================================
# Training set:
#   Images: 5858
#   Masks: 5858
#   Match: ✓
#
# Validation set:
#   Images: 1256
#   Masks: 1256
#   Match: ✓
#
# Test set:
#   Images: 1256
#   Masks: 1256
#   Match: ✓
#
# Total processed images: 8370

# %% [markdown]
# ## Copy Processed Data to Workspace
#
# Organize split datasets into separate directories with images and masks subdirectories.

# %%
# Display sample files
print("\n" + "="*60)
print("SAMPLE FILES")
print("="*60)

train_img_dir = train_dir / 'images'
train_mask_dir = train_dir / 'masks'

sample_images = sorted(list(train_img_dir.glob('*')))[:5]
sample_masks = sorted(list(train_mask_dir.glob('*')))[:5]

print("\nFirst 5 training image-mask pairs:")
for img_path, mask_path in zip(sample_images, sample_masks):
    print(f"  {img_path.name} <-> {mask_path.name}")

print("\n" + "="*60)
print("Data processing complete!")
print("="*60)
print(f"\nProcessed data is available at:")
print(f"  Training: {train_dir}")
print(f"  Validation: {val_dir}")
print(f"  Test: {test_dir}")
print(f"\nProcessing report saved at:")
print(f"  {processed_data_path / 'processing_report.json'}")
# Out:
# ============================================================
# SAMPLE FILES
# ============================================================
#
# First 5 training image-mask pairs:
#   image_000000.png <-> mask_000000.png
#   image_000001.png <-> mask_000001.png
#   image_000002.png <-> mask_000002.png
#   image_000003.png <-> mask_000003.png
#   image_000004.png <-> mask_000004.png
#
# ============================================================
# Data processing complete!
# ============================================================
#
# Processed data is available at:
#   Training: /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/processed/train
#   Validation: /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/processed/val
#   Test: /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/processed/test
#
# Processing report saved at:
#   /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/processed/processing_report.json

# %% [markdown]
# ## Summary
#
# Dataset processing complete. Processed data is organized in:
# - `data/processed/train/` - Training images and masks
# - `data/processed/val/` - Validation images and masks
# - `data/processed/test/` - Test images and masks
#
# Raw data remains in `data/raw/`. Processed data is available in `data/processed/` for experiments.

# %% [markdown]
# ## FAU Dataset Diagnostic
#
# Analyze which FAU pairs were found and which were missed to avoid duplication when fixing pairing logic.

# %%
from fau_diagnostic import diagnose_fau_dataset, print_fau_diagnostic_report

# Run diagnostic on FAU dataset
fau_raw_path = project_root / 'data' / 'raw' / 'FAU'
fau_diagnostic = diagnose_fau_dataset(fau_raw_path)

# Print detailed report
print_fau_diagnostic_report(fau_diagnostic)
# Out:
# ================================================================================
# FAU DATASET DIAGNOSTIC REPORT
# ================================================================================
#
# SUMMARY:
#   Found pairs: 105
#   Images without masks: 4141
#   Masks without images: 5704
#   Total images found: 4246
#   Total masks found: 5852
#
# FOLDER STATISTICS:
#   benchmark_data/C1_panasonic:
#     Images: 96
#     Masks: 15
#     Pairs: 16
#     Match rate: 16.7%
#   benchmark_data/C2_canon:
#     Images: 108
#     Masks: 12
#     Pairs: 12
#     Match rate: 11.1%
#   benchmark_data/C3_nikon:
#     Images: 104
#     Masks: 22
#     Pairs: 12
#     Match rate: 11.5%
#   benchmark_data/C4_flickr:
#     Images: 146
#     Masks: 12
#     Pairs: 14
#     Match rate: 9.6%
#   jpeg/1:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/10:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/11:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/12:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/13:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/14:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/15:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/16:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/17:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/18:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/19:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/2:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/20:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/21:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/22:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/23:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/24:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/25:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/26:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/27:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/28:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/29:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/3:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/30:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/31:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/32:
#     Images: 18
#     Masks: 45
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/33:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/34:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/35:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/36:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/37:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/38:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/39:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/4:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/40:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/41:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/42:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/43:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/44:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/45:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/46:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/47:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/48:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/5:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/6:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/7:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/8:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   jpeg/9:
#     Images: 18
#     Masks: 27
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/1:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/10:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/11:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/12:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/13:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/14:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/15:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/16:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/17:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/18:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/19:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/2:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/20:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/21:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/22:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/23:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/24:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/25:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/26:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/27:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/28:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/29:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/3:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/30:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/31:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/32:
#     Images: 11
#     Masks: 28
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/33:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/34:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/35:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/36:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/37:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/38:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/39:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/4:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/40:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/41:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/42:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/43:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/44:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/45:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/46:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/47:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/48:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/5:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/6:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/7:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/8:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   lnoise/9:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   nul/1:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/10:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/11:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/12:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/13:
#     Images: 2
#     Masks: 3
#     Pairs: 2
#     Match rate: 100.0%
#   nul/14:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/15:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/16:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/17:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/18:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/19:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/2:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/20:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/21:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/22:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/23:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/24:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/25:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/26:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/27:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/28:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/29:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/3:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/30:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/31:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/32:
#     Images: 2
#     Masks: 5
#     Pairs: 0
#     Match rate: 0.0%
#   nul/33:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/34:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/35:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/36:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/37:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/38:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/39:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/4:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/40:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/41:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/42:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/43:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/44:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/45:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/46:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/47:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/48:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/5:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/6:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/7:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/8:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   nul/9:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   orig:
#     Images: 96
#     Masks: 98
#     Pairs: 49
#     Match rate: 51.0%
#   rot/1:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/10:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/11:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/12:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/13:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/14:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/15:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/16:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/17:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/18:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/19:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/2:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/20:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/21:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/22:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/23:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/24:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/25:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/26:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/27:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/28:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/29:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/3:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/30:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/31:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/32:
#     Images: 11
#     Masks: 28
#     Pairs: 0
#     Match rate: 0.0%
#   rot/33:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/34:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/35:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/36:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/37:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/38:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/39:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/4:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/40:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/41:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/42:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/43:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/44:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/45:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/46:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/47:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/48:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/5:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/6:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/7:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/8:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rot/9:
#     Images: 11
#     Masks: 17
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/1:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/10:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/11:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/12:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/13:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/14:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/15:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/16:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/17:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/18:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/19:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/2:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/20:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/21:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/22:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/23:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/24:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/25:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/26:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/27:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/28:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/29:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/3:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/30:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/31:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/32:
#     Images: 2
#     Masks: 5
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/33:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/34:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/35:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/36:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/37:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/38:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/39:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/4:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/40:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/41:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/42:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/43:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/44:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/45:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/46:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/47:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/48:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/5:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/6:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/7:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/8:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra/9:
#     Images: 2
#     Masks: 3
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/1:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/10:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/11:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/12:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/13:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/14:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/15:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/16:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/17:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/18:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/19:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/2:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/20:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/21:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/22:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/23:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/24:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/25:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/26:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/27:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/28:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/29:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/3:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/30:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/31:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/32:
#     Images: 4
#     Masks: 10
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/33:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/34:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/35:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/36:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/37:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/38:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/39:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/4:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/40:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/41:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/42:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/43:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/44:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/45:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/46:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/47:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/48:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/5:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/6:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/7:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/8:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   rotExtra2/9:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scale/1:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/10:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/11:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/12:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/13:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/14:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/15:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/16:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/17:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/18:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/19:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/2:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/20:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/21:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/22:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/23:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/24:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/25:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/26:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/27:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/28:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/29:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/3:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/30:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/31:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/32:
#     Images: 21
#     Masks: 53
#     Pairs: 0
#     Match rate: 0.0%
#   scale/33:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/34:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/35:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/36:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/37:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/38:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/39:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/4:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/40:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/41:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/42:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/43:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/44:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/45:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/46:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/47:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/48:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/5:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/6:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/7:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/8:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scale/9:
#     Images: 21
#     Masks: 32
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/1:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/10:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/11:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/12:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/13:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/14:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/15:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/16:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/17:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/18:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/19:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/2:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/20:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/21:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/22:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/23:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/24:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/25:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/26:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/27:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/28:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/29:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/3:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/30:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/31:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/32:
#     Images: 4
#     Masks: 10
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/33:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/34:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/35:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/36:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/37:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/38:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/39:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/4:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/40:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/41:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/42:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/43:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/44:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/45:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/46:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/47:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/48:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/5:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/6:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/7:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/8:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra/9:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/1:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/10:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/11:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/12:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/13:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/14:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/15:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/16:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/17:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/18:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/19:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/2:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/20:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/21:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/22:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/23:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/24:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/25:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/26:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/27:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/28:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/29:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/3:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/30:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/31:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/32:
#     Images: 4
#     Masks: 10
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/33:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/34:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/35:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/36:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/37:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/38:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/39:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/4:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/40:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/41:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/42:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/43:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/44:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/45:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/46:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/47:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/48:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/5:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/6:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/7:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/8:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#   scaleExtra2/9:
#     Images: 4
#     Masks: 6
#     Pairs: 0
#     Match rate: 0.0%
#
# PATTERN STATISTICS:
#   benchmark_data/C1_panasonic/_copy:
#     Found: 16
#     Missing: 0
#   benchmark_data/C1_panasonic/no_match:
#     Found: 0
#     Missing: 80
#   benchmark_data/C2_canon/_copy:
#     Found: 12
#     Missing: 0
#   benchmark_data/C2_canon/no_match:
#     Found: 0
#     Missing: 96
#   benchmark_data/C3_nikon/_copy:
#     Found: 12
#     Missing: 0
#   benchmark_data/C3_nikon/no_match:
#     Found: 0
#     Missing: 92
#   benchmark_data/C4_flickr/_copy:
#     Found: 14
#     Missing: 0
#   benchmark_data/C4_flickr/no_match:
#     Found: 0
#     Missing: 132
#   jpeg/1/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/10/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/11/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/12/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/13/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/14/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/15/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/16/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/17/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/18/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/19/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/2/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/20/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/21/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/22/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/23/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/24/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/25/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/26/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/27/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/28/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/29/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/3/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/30/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/31/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/32/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/33/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/34/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/35/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/36/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/37/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/38/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/39/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/4/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/40/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/41/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/42/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/43/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/44/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/45/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/46/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/47/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/48/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/5/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/6/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/7/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/8/no_match:
#     Found: 0
#     Missing: 18
#   jpeg/9/no_match:
#     Found: 0
#     Missing: 18
#   lnoise/1/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/10/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/11/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/12/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/13/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/14/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/15/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/16/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/17/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/18/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/19/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/2/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/20/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/21/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/22/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/23/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/24/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/25/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/26/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/27/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/28/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/29/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/3/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/30/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/31/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/32/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/33/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/34/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/35/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/36/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/37/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/38/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/39/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/4/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/40/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/41/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/42/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/43/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/44/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/45/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/46/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/47/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/48/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/5/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/6/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/7/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/8/no_match:
#     Found: 0
#     Missing: 11
#   lnoise/9/no_match:
#     Found: 0
#     Missing: 11
#   nul/1/no_match:
#     Found: 0
#     Missing: 2
#   nul/10/no_match:
#     Found: 0
#     Missing: 2
#   nul/11/no_match:
#     Found: 0
#     Missing: 2
#   nul/12/no_match:
#     Found: 0
#     Missing: 2
#   nul/13/_gt:
#     Found: 2
#     Missing: 0
#   nul/14/no_match:
#     Found: 0
#     Missing: 2
#   nul/15/no_match:
#     Found: 0
#     Missing: 2
#   nul/16/no_match:
#     Found: 0
#     Missing: 2
#   nul/17/no_match:
#     Found: 0
#     Missing: 2
#   nul/18/no_match:
#     Found: 0
#     Missing: 2
#   nul/19/no_match:
#     Found: 0
#     Missing: 2
#   nul/2/no_match:
#     Found: 0
#     Missing: 2
#   nul/20/no_match:
#     Found: 0
#     Missing: 2
#   nul/21/no_match:
#     Found: 0
#     Missing: 2
#   nul/22/no_match:
#     Found: 0
#     Missing: 2
#   nul/23/no_match:
#     Found: 0
#     Missing: 2
#   nul/24/no_match:
#     Found: 0
#     Missing: 2
#   nul/25/no_match:
#     Found: 0
#     Missing: 2
#   nul/26/no_match:
#     Found: 0
#     Missing: 2
#   nul/27/no_match:
#     Found: 0
#     Missing: 2
#   nul/28/no_match:
#     Found: 0
#     Missing: 2
#   nul/29/no_match:
#     Found: 0
#     Missing: 2
#   nul/3/no_match:
#     Found: 0
#     Missing: 2
#   nul/30/no_match:
#     Found: 0
#     Missing: 2
#   nul/31/no_match:
#     Found: 0
#     Missing: 2
#   nul/32/no_match:
#     Found: 0
#     Missing: 2
#   nul/33/no_match:
#     Found: 0
#     Missing: 2
#   nul/34/no_match:
#     Found: 0
#     Missing: 2
#   nul/35/no_match:
#     Found: 0
#     Missing: 2
#   nul/36/no_match:
#     Found: 0
#     Missing: 2
#   nul/37/no_match:
#     Found: 0
#     Missing: 2
#   nul/38/no_match:
#     Found: 0
#     Missing: 2
#   nul/39/no_match:
#     Found: 0
#     Missing: 2
#   nul/4/no_match:
#     Found: 0
#     Missing: 2
#   nul/40/no_match:
#     Found: 0
#     Missing: 2
#   nul/41/no_match:
#     Found: 0
#     Missing: 2
#   nul/42/no_match:
#     Found: 0
#     Missing: 2
#   nul/43/no_match:
#     Found: 0
#     Missing: 2
#   nul/44/no_match:
#     Found: 0
#     Missing: 2
#   nul/45/no_match:
#     Found: 0
#     Missing: 2
#   nul/46/no_match:
#     Found: 0
#     Missing: 2
#   nul/47/no_match:
#     Found: 0
#     Missing: 2
#   nul/48/no_match:
#     Found: 0
#     Missing: 2
#   nul/5/no_match:
#     Found: 0
#     Missing: 2
#   nul/6/no_match:
#     Found: 0
#     Missing: 2
#   nul/7/no_match:
#     Found: 0
#     Missing: 2
#   nul/8/no_match:
#     Found: 0
#     Missing: 2
#   nul/9/no_match:
#     Found: 0
#     Missing: 2
#   orig/_gt:
#     Found: 49
#     Missing: 0
#   orig/no_match:
#     Found: 0
#     Missing: 47
#   rot/1/no_match:
#     Found: 0
#     Missing: 11
#   rot/10/no_match:
#     Found: 0
#     Missing: 11
#   rot/11/no_match:
#     Found: 0
#     Missing: 11
#   rot/12/no_match:
#     Found: 0
#     Missing: 11
#   rot/13/no_match:
#     Found: 0
#     Missing: 11
#   rot/14/no_match:
#     Found: 0
#     Missing: 11
#   rot/15/no_match:
#     Found: 0
#     Missing: 11
#   rot/16/no_match:
#     Found: 0
#     Missing: 11
#   rot/17/no_match:
#     Found: 0
#     Missing: 11
#   rot/18/no_match:
#     Found: 0
#     Missing: 11
#   rot/19/no_match:
#     Found: 0
#     Missing: 11
#   rot/2/no_match:
#     Found: 0
#     Missing: 11
#   rot/20/no_match:
#     Found: 0
#     Missing: 11
#   rot/21/no_match:
#     Found: 0
#     Missing: 11
#   rot/22/no_match:
#     Found: 0
#     Missing: 11
#   rot/23/no_match:
#     Found: 0
#     Missing: 11
#   rot/24/no_match:
#     Found: 0
#     Missing: 11
#   rot/25/no_match:
#     Found: 0
#     Missing: 11
#   rot/26/no_match:
#     Found: 0
#     Missing: 11
#   rot/27/no_match:
#     Found: 0
#     Missing: 11
#   rot/28/no_match:
#     Found: 0
#     Missing: 11
#   rot/29/no_match:
#     Found: 0
#     Missing: 11
#   rot/3/no_match:
#     Found: 0
#     Missing: 11
#   rot/30/no_match:
#     Found: 0
#     Missing: 11
#   rot/31/no_match:
#     Found: 0
#     Missing: 11
#   rot/32/no_match:
#     Found: 0
#     Missing: 11
#   rot/33/no_match:
#     Found: 0
#     Missing: 11
#   rot/34/no_match:
#     Found: 0
#     Missing: 11
#   rot/35/no_match:
#     Found: 0
#     Missing: 11
#   rot/36/no_match:
#     Found: 0
#     Missing: 11
#   rot/37/no_match:
#     Found: 0
#     Missing: 11
#   rot/38/no_match:
#     Found: 0
#     Missing: 11
#   rot/39/no_match:
#     Found: 0
#     Missing: 11
#   rot/4/no_match:
#     Found: 0
#     Missing: 11
#   rot/40/no_match:
#     Found: 0
#     Missing: 11
#   rot/41/no_match:
#     Found: 0
#     Missing: 11
#   rot/42/no_match:
#     Found: 0
#     Missing: 11
#   rot/43/no_match:
#     Found: 0
#     Missing: 11
#   rot/44/no_match:
#     Found: 0
#     Missing: 11
#   rot/45/no_match:
#     Found: 0
#     Missing: 11
#   rot/46/no_match:
#     Found: 0
#     Missing: 11
#   rot/47/no_match:
#     Found: 0
#     Missing: 11
#   rot/48/no_match:
#     Found: 0
#     Missing: 11
#   rot/5/no_match:
#     Found: 0
#     Missing: 11
#   rot/6/no_match:
#     Found: 0
#     Missing: 11
#   rot/7/no_match:
#     Found: 0
#     Missing: 11
#   rot/8/no_match:
#     Found: 0
#     Missing: 11
#   rot/9/no_match:
#     Found: 0
#     Missing: 11
#   rotExtra/1/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/10/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/11/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/12/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/13/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/14/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/15/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/16/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/17/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/18/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/19/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/2/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/20/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/21/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/22/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/23/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/24/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/25/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/26/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/27/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/28/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/29/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/3/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/30/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/31/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/32/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/33/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/34/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/35/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/36/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/37/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/38/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/39/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/4/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/40/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/41/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/42/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/43/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/44/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/45/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/46/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/47/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/48/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/5/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/6/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/7/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/8/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra/9/no_match:
#     Found: 0
#     Missing: 2
#   rotExtra2/1/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/10/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/11/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/12/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/13/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/14/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/15/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/16/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/17/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/18/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/19/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/2/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/20/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/21/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/22/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/23/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/24/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/25/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/26/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/27/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/28/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/29/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/3/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/30/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/31/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/32/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/33/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/34/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/35/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/36/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/37/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/38/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/39/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/4/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/40/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/41/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/42/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/43/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/44/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/45/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/46/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/47/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/48/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/5/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/6/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/7/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/8/no_match:
#     Found: 0
#     Missing: 4
#   rotExtra2/9/no_match:
#     Found: 0
#     Missing: 4
#   scale/1/no_match:
#     Found: 0
#     Missing: 21
#   scale/10/no_match:
#     Found: 0
#     Missing: 21
#   scale/11/no_match:
#     Found: 0
#     Missing: 21
#   scale/12/no_match:
#     Found: 0
#     Missing: 21
#   scale/13/no_match:
#     Found: 0
#     Missing: 21
#   scale/14/no_match:
#     Found: 0
#     Missing: 21
#   scale/15/no_match:
#     Found: 0
#     Missing: 21
#   scale/16/no_match:
#     Found: 0
#     Missing: 21
#   scale/17/no_match:
#     Found: 0
#     Missing: 21
#   scale/18/no_match:
#     Found: 0
#     Missing: 21
#   scale/19/no_match:
#     Found: 0
#     Missing: 21
#   scale/2/no_match:
#     Found: 0
#     Missing: 21
#   scale/20/no_match:
#     Found: 0
#     Missing: 21
#   scale/21/no_match:
#     Found: 0
#     Missing: 21
#   scale/22/no_match:
#     Found: 0
#     Missing: 21
#   scale/23/no_match:
#     Found: 0
#     Missing: 21
#   scale/24/no_match:
#     Found: 0
#     Missing: 21
#   scale/25/no_match:
#     Found: 0
#     Missing: 21
#   scale/26/no_match:
#     Found: 0
#     Missing: 21
#   scale/27/no_match:
#     Found: 0
#     Missing: 21
#   scale/28/no_match:
#     Found: 0
#     Missing: 21
#   scale/29/no_match:
#     Found: 0
#     Missing: 21
#   scale/3/no_match:
#     Found: 0
#     Missing: 21
#   scale/30/no_match:
#     Found: 0
#     Missing: 21
#   scale/31/no_match:
#     Found: 0
#     Missing: 21
#   scale/32/no_match:
#     Found: 0
#     Missing: 21
#   scale/33/no_match:
#     Found: 0
#     Missing: 21
#   scale/34/no_match:
#     Found: 0
#     Missing: 21
#   scale/35/no_match:
#     Found: 0
#     Missing: 21
#   scale/36/no_match:
#     Found: 0
#     Missing: 21
#   scale/37/no_match:
#     Found: 0
#     Missing: 21
#   scale/38/no_match:
#     Found: 0
#     Missing: 21
#   scale/39/no_match:
#     Found: 0
#     Missing: 21
#   scale/4/no_match:
#     Found: 0
#     Missing: 21
#   scale/40/no_match:
#     Found: 0
#     Missing: 21
#   scale/41/no_match:
#     Found: 0
#     Missing: 21
#   scale/42/no_match:
#     Found: 0
#     Missing: 21
#   scale/43/no_match:
#     Found: 0
#     Missing: 21
#   scale/44/no_match:
#     Found: 0
#     Missing: 21
#   scale/45/no_match:
#     Found: 0
#     Missing: 21
#   scale/46/no_match:
#     Found: 0
#     Missing: 21
#   scale/47/no_match:
#     Found: 0
#     Missing: 21
#   scale/48/no_match:
#     Found: 0
#     Missing: 21
#   scale/5/no_match:
#     Found: 0
#     Missing: 21
#   scale/6/no_match:
#     Found: 0
#     Missing: 21
#   scale/7/no_match:
#     Found: 0
#     Missing: 21
#   scale/8/no_match:
#     Found: 0
#     Missing: 21
#   scale/9/no_match:
#     Found: 0
#     Missing: 21
#   scaleExtra/1/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/10/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/11/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/12/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/13/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/14/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/15/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/16/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/17/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/18/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/19/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/2/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/20/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/21/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/22/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/23/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/24/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/25/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/26/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/27/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/28/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/29/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/3/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/30/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/31/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/32/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/33/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/34/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/35/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/36/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/37/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/38/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/39/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/4/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/40/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/41/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/42/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/43/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/44/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/45/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/46/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/47/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/48/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/5/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/6/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/7/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/8/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra/9/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/1/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/10/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/11/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/12/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/13/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/14/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/15/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/16/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/17/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/18/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/19/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/2/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/20/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/21/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/22/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/23/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/24/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/25/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/26/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/27/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/28/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/29/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/3/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/30/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/31/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/32/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/33/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/34/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/35/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/36/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/37/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/38/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/39/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/4/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/40/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/41/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/42/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/43/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/44/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/45/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/46/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/47/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/48/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/5/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/6/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/7/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/8/no_match:
#     Found: 0
#     Missing: 4
#   scaleExtra2/9/no_match:
#     Found: 0
#     Missing: 4
#
#  SAMPLE MISSING IMAGES (first 10):
#     knight_moves_5_alpha.png
#     threehundred_copy.png
#     mykene_2_trim_alpha.png
#     malawi_copy.png
#     knight_moves_2.png
#     threehundred_5_alpha.png
#     knight_moves_3.png
#     knight_moves_3_trim_alpha.png
#     sailing_1_alpha.png
#     sailing_1_trim_alpha.png
#
#  SAMPLE MISSING MASKS (first 10):
#     red_tower_copy_bearb.png
#     ship_number_copy_bearb.png
#     hedge_copy_bearb.png
#     mask_2_trim.png
#     mask_2_alpha.png
#     mask_2.png
#     mask_1.png
#     mask_1_trim_alpha.png
#     mask_1_trim.png
#     mask_1_alpha.png
#
# SUCCESSFULLY PAIRED (first 10):
#     sailing.png <-> sailing_copy.png
#     scotland.png <-> scotland_copy.png
#     mykene.png <-> mykene_copy.png
#     clean_walls.png <-> clean_walls_copy.png
#     knight_moves.png <-> knight_moves_copy.png
#     threehundred.png <-> threehundred_copy.png
#     kore.png <-> kore_copy.png
#     statue.png <-> statue_copy.png
#     tree.png <-> tree_copy.png
#     giraffe.png <-> giraffe_copy.png
#
# ================================================================================

# %%
# Save found pairs to a file for reference
import json

fau_found_pairs_file = project_root / 'data' / 'processed' / 'fau_found_pairs.json'
with open(fau_found_pairs_file, 'w') as f:
    json.dump({
        'found_pairs': fau_diagnostic['found_pairs'],
        'folder_stats': dict(fau_diagnostic['folder_stats']),
        'pattern_stats': dict(fau_diagnostic['pattern_stats']),
        'missing_images_count': len(fau_diagnostic['missing_images']),
        'missing_masks_count': len(fau_diagnostic['missing_masks'])
    }, f, indent=2)

print(f"\nFound pairs saved to: {fau_found_pairs_file}")
print(f"\nUse this file to check which pairs were already processed.")
print(f"   When fixing FAU pairing logic, exclude these {len(fau_diagnostic['found_pairs'])} pairs to avoid duplication.")
print(f"\nSummary:")
print(f"  - Found pairs: {len(fau_diagnostic['found_pairs'])}")
print(f"  - Images without masks: {len(fau_diagnostic['missing_images'])}")
print(f"  - Masks without images: {len(fau_diagnostic['missing_masks'])}")
# Out:
# Found pairs saved to: /Users/osamahshamsan/Desktop/Master/CV/TRACE/data/processed/fau_found_pairs.json
#
# Use this file to check which pairs were already processed.
#    When fixing FAU pairing logic, exclude these 105 pairs to avoid duplication.
#
# Summary:
#   - Found pairs: 105
#   - Images without masks: 4141
#   - Masks without images: 5704

# %%
from add_fau_pairs import add_new_fau_pairs

new_count = add_new_fau_pairs(
    raw_data_dir=str(project_root / 'data' / 'raw'),
    processed_data_dir=str(project_root / 'data' / 'processed'),
    config=config
)
print(f"Added {new_count} new FAU pairs")

# %%
from dataset_coverage_check import check_all_datasets, print_coverage_report

results = check_all_datasets(
    raw_data_dir=str(project_root / 'data' / 'raw'),
    processed_data_dir=str(project_root / 'data' / 'processed'),
    config=config
)

print_coverage_report(results)
# Out:
# ================================================================================
# DATASET PROCESSING COVERAGE REPORT
# ================================================================================
#
# ✗ CASIA2:
#   Found: 3216 pairs
#   Expected: 3274 pairs
#   Missing: 58 pairs
#   Coverage: 98.2%
#   Status: incomplete
#
# ✓ COVERAGE:
#   Found: 100 pairs
#   Expected: 100 pairs
#   Missing: 0 pairs
#   Coverage: 100.0%
#   Status: complete
#
# ✗ FAU:
#   Found: 54 pairs
#   Expected: 105 pairs
#   Missing: 51 pairs
#   Coverage: 51.4%
#   Status: incomplete
#
# ✗ MICC:
#   Found: 0 pairs
#   Expected: 160 pairs
#   Missing: 160 pairs
#   Coverage: 0.0%
#   Status: incomplete
#
# ✓ comofod_small:
#   Found: 5000 pairs
#   Expected: 5000 pairs
#   Missing: 0 pairs
#   Coverage: 100.0%
#   Status: complete
#
# ================================================================================
# SUMMARY:
#   Total found: 8370 pairs
#   Total expected: 8639 pairs
#   Total missing: 269 pairs
#   Overall coverage: 96.9%
# ================================================================================
#
# DATASETS NEEDING ATTENTION:
#   - CASIA2: Missing 58 pairs (98.2% coverage)
#   - MICC: Missing 160 pairs (0.0% coverage)
#   - FAU: Missing 51 pairs (51.4% coverage)
